# %% [markdown]
# # Import datasets
#
# We start by reading our datasets

# %% [markdown]
# ## IMDB Dataset.csv (66.2 MB)

# %%
import pandas as pd

# Cargar el dataset completo

df_imdb = pd.read_csv('../src/data/IMDB Dataset.csv')

# Verificar la estructura del dataset
print(df_imdb.info())
print(df_imdb.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB
# None
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='sentiment', data=df_imdb)
plt.title("Distribución de Sentimientos (IMDB)")
plt.show()

# %%
df_imdb['review_length'] = df_imdb['review'].apply(len)
sns.histplot(df_imdb['review_length'], kde=True)
plt.title("Distribución de Longitud de Reseñas (IMDB)")
plt.show()

# %%
df_reviews = pd.read_csv('../src/data/Reviews.csv', usecols=['review', 'sentiment'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 df_reviews = pd.read_csv('../src/data/Reviews.csv', usecols=['review', 'sentiment'])
#
# ...

# %% [markdown]
# ##

# %%
import pandas as pd

# ! agregar datasets a mi carpeta de data. 

# df = pd.read_csv("../data/...")
# df.head()
